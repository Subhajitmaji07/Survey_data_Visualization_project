# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/RISE_Internship/survey_data.csv")

# %% [markdown]
# # **Data Preprocessing**

# %%
df.head()
# Out:
#    RespondentID PreferredPlatform Satisfaction  Rating
# 0             1           YouTube          Yes       5
# 1             2         Instagram          Yes       4
# 2             3          Facebook           No       2
# 3             4           YouTube          Yes       5
# 4             5         Instagram           No       3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   RespondentID       10 non-null     int64
#  1   PreferredPlatform  10 non-null     object
#  2   Satisfaction       10 non-null     object
#  3   Rating             10 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 452.0+ bytes

# %%
df.isnull().sum()
# Out:
# RespondentID         0
# PreferredPlatform    0
# Satisfaction         0
# Rating               0
# dtype: int64

# %% [markdown]
# # **Visualization**

# %%
# Bar chart - Satisfaction vs Count
satisfaction_counts = df['Satisfaction'].value_counts()
satisfaction_counts.plot(kind='bar', color='green')
plt.title('Satisfaction Count')
plt.xlabel('Satisfaction')
plt.ylabel('Number of Responses')
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/RISE_Internship/survey_data_output/bar_satisfaction.png')
plt.show()

# %%
# Pie chart - Platform Preference
platform_counts = df['PreferredPlatform'].value_counts()
platform_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Preferred Platforms')
plt.ylabel('')
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/RISE_Internship/survey_data_output/pie_platform.png')
plt.show()

# %%
# Heatmap - Ratings by Platform
pivot = df.pivot_table(values='Rating', index='PreferredPlatform', columns='Satisfaction')
sns.heatmap(pivot, annot=True, cmap='coolwarm')
plt.title('Ratings Heatmap: Platform vs Satisfaction')
plt.tight_layout()
plt.savefig('/content/drive/MyDrive/RISE_Internship/survey_data_output/heatmap_rating.png')
plt.show()
